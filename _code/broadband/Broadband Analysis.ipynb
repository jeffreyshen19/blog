# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Description
# * LogRecNo: A logical record number created to relate the broadband deployment tables to the Imputations Table
# * Provider_Id: filing number (assigned by FCC)
# * FRN: FCC registration number
# * ProviderName: Provider name
# * DBAName: "Doing business as" name
# * HoldingCompanyName: Holding company name (as filed on Form 477)
# * HocoNum: Holding company number (assigned by FCC)
# * HocoFinal: Holding company name (attribution by FCC)
# * StateAbbr: 2-letter state abbreviation used by the US Postal Service
# * BlockCode: 15-digit census block code used in the 2010 US Census
# * TechCode: 2-digit code indicating the Technology of Transmission used to offer broadband service
# * Consumer: (0/1) where 1 = Provider can or does offer consumer/mass market/residential service in the block
# * MaxAdDown: Maximum advertised downstream speed/bandwidth offered by the provider in the block for Consumer service
# * MaxAdUp: Maximum advertised upstream speed/bandwidth offered by the provider in the block for Consumer service
# * Business: (0/1) where 1 = Provider can or does offer business/government service in the block
# * MaxCIRDown: Maximum contractual downstream bandwidth offered by the provider in the block for Business service (filer directed to report 0 if the contracted service is sold on a "best efforts" basis without a guaranteed data-throughput rate)
# * MaxCIRUp: Maximum contractual upstream bandwidth offered by the provider in the block for Business service (filer directed to report 0 if the contracted service is sold on a "best efforts" basis without a guaranteed data-throughput rate)

# %%
df = pd.read_csv('fbd_us_without_satellite_dec2017_v2.csv', delimiter = ',', encoding='latin-1')
df.head()
# Out:
#    LogRecNo  Provider_Id      FRN                                ProviderName  \
# 0         1        34040  1565829  Beaver Creek Cooperative Telephone Company
# 1         2        34040  1565829  Beaver Creek Cooperative Telephone Company
# 2         3        34040  1565829  Beaver Creek Cooperative Telephone Company
# 3         4        34040  1565829  Beaver Creek Cooperative Telephone Company
# 4         5        34040  1565829  Beaver Creek Cooperative Telephone Company
#
#                                      DBAName  \
# 0  Beavercreek Cooperative Telephone Company
# 1  Beavercreek Cooperative Telephone Company
# 2  Beavercreek Cooperative Telephone Company
# 3  Beavercreek Cooperative Telephone Company
# 4  Beavercreek Cooperative Telephone Company
#
#                            HoldingCompanyName  HocoNum  \
# 0  Beaver Creek Cooperative Telephone Company   130104
# 1  Beaver Creek Cooperative Telephone Company   130104
# 2  Beaver Creek Cooperative Telephone Company   130104
# 3  Beaver Creek Cooperative Telephone Company   130104
# 4  Beaver Creek Cooperative Telephone Company   130104
#
#                                     HocoFinal StateAbbr        BlockCode  \
# 0  Beaver Creek Cooperative Telephone Company        OR  410050237001006
# 1  Beaver Creek Cooperative Telephone Company        OR  410050230022026
# 2  Beaver Creek Cooperative Telephone Company        OR  410050237001011
# 3  Beaver Creek Cooperative Telephone Company        OR  410050237001013
# 4  Beaver Creek Cooperative Telephone Company        OR  410050237001016
#
#    TechCode  Consumer  MaxAdDown  MaxAdUp  Business  MaxCIRDown  MaxCIRUp
# 0        11         1       15.0      1.0         1        15.0       1.0
# 1        11         1       15.0      1.0         1        15.0       1.0
# 2        11         1       15.0      1.0         1        15.0       1.0
# 3        11         1       15.0      1.0         1        15.0       1.0
# 4        11         1       15.0      1.0         1        15.0       1.0

# %%
df.head(10)
# Out:
