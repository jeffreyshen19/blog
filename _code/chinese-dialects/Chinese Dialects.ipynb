# %% [markdown]
# # Mapping Chinese Dialects in the U.S.

# %% [markdown]
# ## Data Processing
# Data is presented as an excel workbook, where each sheet is a county. Let's parse this into a more usable csv format

# %%
import pandas as pd

# %%
counties = pd.read_excel(r'2009-2013-acs-lang-tables-county.xls', sheet_name='Contents')
counties.head()
# Out:
#    Table                      County
# 0      1  Anchorage Municipality, AK
# 1      2         Maricopa County, AZ
# 2      3           Navajo County, AZ
# 3      4             Pima County, AZ
# 4      5          Alameda County, CA

# %%
language_by_county = []

for i, row in counties.iterrows():
    print(i, row["County"])
    county_df = pd.read_excel(r'2009-2013-acs-lang-tables-county.xls', sheet_name=row["County"], skiprows=4)
    county_df.columns = ["Language", "Number of Speakers", "Margin of Error 1", "Speak English Less Than Very Well", "Margin of Error 2"]

    # Get all rows for Chinese Language 
    in_correct_section = False 
    chinese_languages = []

    for i, r in county_df.iterrows():
        # Find the rows which contain Chinese language, and Chinese dialect data
        if type(r["Language"]) == str and r["Language"].startswith(".Chinese"): in_correct_section = True
        if type(r["Language"]) == str and in_correct_section and not r["Language"].startswith("..") and not r["Language"].startswith(".Chinese"): in_correct_section = False 

        if in_correct_section: chinese_languages.append({
            "language": r["Language"],
            "speakers": r["Number of Speakers"],
            "speak_english_less_than_very_well": r["Speak English Less Than Very Well"]
        })

    language_by_county.append((row["County"], chinese_languages))
# Out:
# 0 Anchorage Municipality, AK
# 1 Maricopa County, AZ
# 2 Navajo County, AZ
# 3 Pima County, AZ
# 4 Alameda County, CA
# 5 Contra Costa County, CA
# 6 Fresno County, CA
# 7 Kern County, CA
# 8 Los Angeles County, CA
# 9 Monterey County, CA
# 10 Orange County, CA
# 11 Placer County, CA
# 12 Riverside County, CA
# 13 Sacramento County, CA
# 14 San Bernardino County, CA
# 15 San Diego County, CA
# 16 San Francisco County, CA
# 17 San Joaquin County, CA
# 18 San Mateo County, CA
# 19 Santa Barbara County, CA
# 20 Santa Clara County, CA
# 21 Solano County, CA
# 22 Sonoma County, CA
# 23 Stanislaus County, CA
# 24 Ventura County, CA
# 25 Yolo County, CA
# 26 Arapahoe County, CO
# 27 Denver County, CO
# 28 El Paso County, CO
# 29 Fairfield County, CT
# 30 Hartford County, CT
# 31 New Haven County, CT
# 32 New Castle County, DE
# 33 District of Columbia, DC
# 34 Broward County, FL
# 35 Collier County, FL
# 36 Duval County, FL
# 37 Hillsborough County, FL
# 38 Lee County, FL
# 39 Miami-Dade County, FL
# 40 Orange County, FL
# 41 Palm Beach County, FL
# 42 Pinellas County, FL
# 43 Cobb County, GA
# 44 DeKalb County, GA
# 45 Fulton County, GA
# 46 Gwinnett County, GA
# 47 Hawaii County, HI
# 48 Honolulu County, HI
# 49 Maui County, HI
# 50 Cook County, IL
# 51 DuPage County, IL
# 52 Kane County, IL
# 53 Lake County, IL
# 54 Will County, IL
# 55 Marion County, IN
# 56 Polk County, IA
# 57 Johnson County, KS
# 58 Jefferson County, KY
# 59 Jefferson Parish, LA
# 60 Anne Arundel County, MD
# 61 Baltimore County, MD
# 62 Howard County, MD
# 63 Montgomery County, MD
# 64 Prince George s County, MD
# 65 Baltimore city, MD
# 66 Bristol County, MA
# 67 Essex County, MA
# 68 Hampden County, MA
# 69 Middlesex County, MA
# 70 Norfolk County, MA
# 71 Plymouth County, MA
# 72 Suffolk County, MA
# 73 Worcester County, MA
# 74 Macomb County, MI
# 75 Oakland County, MI
# 76 Washtenaw County, MI
# 77 Wayne County, MI
# 78 Dakota County, MN
# 79 Hennepin County, MN
# 80 Ramsey County, MN
# 81 St. Louis County, MO
# 82 Clark County, NV
# 83 Washoe County, NV
# 84 Hillsborough County, NH
# 85 Atlantic County, NJ
# 86 Bergen County, NJ
# 87 Burlington County, NJ
# 88 Camden County, NJ
# 89 Essex County, NJ
# 90 Hudson County, NJ
# 91 Mercer County, NJ
# 92 Middlesex County, NJ
# 93 Monmouth County, NJ
# 94 Morris County, NJ
# 95 Ocean County, NJ
# 96 Passaic County, NJ
# 97 Somerset County, NJ
# 98 Union County, NJ
# 99 Bernalillo County, NM
# 100 San Juan County, NM
# 101 Albany County, NY
# 102 Bronx County, NY
# 103 Erie County, NY
# 104 Kings County, NY
# 105 Monroe County, NY
# 106 Nassau County, NY
# 107 New York County, NY
# 108 Onondaga County, NY
# 109 Orange County, NY
# 110 Queens County, NY
# 111 Richmond County, NY
# 112 Rockland County, NY
# 113 Suffolk County, NY
# 114 Westchester County, NY
# 115 Guilford County, NC
# 116 Mecklenburg County, NC
# 117 Wake County, NC
# 118 Cuyahoga County, OH
# 119 Franklin County, OH
# 120 Hamilton County, OH
# 121 Oklahoma County, OK
# 122 Multnomah County, OR
# 123 Washington County, OR
# 124 Allegheny County, PA
# 125 Bucks County, PA
# 126 Chester County, PA
# 127 Delaware County, PA
# 128 Lancaster County, PA
# 129 Montgomery County, PA
# 130 Philadelphia County, PA
# 131 Providence County, RI
# 132 Davidson County, TN
# 133 Shelby County, TN
# 134 Bexar County, TX
# 135 Collin County, TX
# 136 Dallas County, TX
# 137 Denton County, TX
# 138 Fort Bend County, TX
# 139 Harris County, TX
# 140 Tarrant County, TX
# 141 Travis County, TX
# 142 Salt Lake County, UT
# 143 Arlington County, VA
# 144 Fairfax County, VA
# 145 Henrico County, VA
# 146 Loudoun County, VA
# 147 Prince William County, VA
# 148 Virginia Beach city, VA
# 149 Clark County, WA
# 150 King County, WA
# 151 Pierce County, WA
# 152 Snohomish County, WA
# 153 Dane County, WI
# 154 Milwaukee County, WI

# %%
language_by_county
# Out:
# [('Anchorage Municipality, AK',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 882,
#     'speak_english_less_than_very_well': 519},
#    {'language': '..Chinese',
#     'speakers': 740,
#     'speak_english_less_than_very_well': 445},
#    {'language': '..Cantonese',
#     'speakers': 40,
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Mandarin',
#     'speakers': 95,
#     'speak_english_less_than_very_well': 65},
#    {'language': '..Formosan',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Maricopa County, AZ',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 20337,
#     'speak_english_less_than_very_well': 10163},
#    {'language': '..Chinese',
#     'speakers': 13750,
#     'speak_english_less_than_very_well': 7445},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Cantonese',
#     'speakers': 2235,
#     'speak_english_less_than_very_well': 1010},
#    {'language': '..Mandarin',
#     'speakers': 3890,
#     'speak_english_less_than_very_well': 1470},
#    {'language': '..Formosan',
#     'speakers': 450,
#     'speak_english_less_than_very_well': 240},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Navajo County, AZ',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 35,
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Chinese',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Mandarin',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Pima County, AZ',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 6334,
#     'speak_english_less_than_very_well': 3074},
#    {'language': '..Chinese',
#     'speakers': 4625,
#     'speak_english_less_than_very_well': 2425},
#    {'language': '..Cantonese',
#     'speakers': 630,
#     'speak_english_less_than_very_well': 325},
#    {'language': '..Mandarin',
#     'speakers': 955,
#     'speak_english_less_than_very_well': 300},
#    {'language': '..Formosan',
#     'speakers': 125,
#     'speak_english_less_than_very_well': 20}]),
#  ('Alameda County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 119759,
#     'speak_english_less_than_very_well': 69344},
#    {'language': '..Chinese',
#     'speakers': 69165,
#     'speak_english_less_than_very_well': 40515},
#    {'language': '..Hakka',
#     'speakers': 45,
#     'speak_english_less_than_very_well': 45},
#    {'language': '..Cantonese',
#     'speakers': 31050,
#     'speak_english_less_than_very_well': 18895},
#    {'language': '..Mandarin',
#     'speakers': 17450,
#     'speak_english_less_than_very_well': 8770},
#    {'language': '..Formosan',
#     'speakers': 1915,
#     'speak_english_less_than_very_well': 1030},
#    {'language': '..Wu',
#     'speakers': 135,
#     'speak_english_less_than_very_well': 80}]),
#  ('Contra Costa County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 31465,
#     'speak_english_less_than_very_well': 15917},
#    {'language': '..Chinese',
#     'speakers': 17545,
#     'speak_english_less_than_very_well': 8900},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Cantonese',
#     'speakers': 7200,
#     'speak_english_less_than_very_well': 3660},
#    {'language': '..Mandarin',
#     'speakers': 5860,
#     'speak_english_less_than_very_well': 2920},
#    {'language': '..Formosan',
#     'speakers': 850,
#     'speak_english_less_than_very_well': 435}]),
#  ('Fresno County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 5014,
#     'speak_english_less_than_very_well': 2666},
#    {'language': '..Chinese',
#     'speakers': 3195,
#     'speak_english_less_than_very_well': 1925},
#    {'language': '..Cantonese',
#     'speakers': 565,
#     'speak_english_less_than_very_well': 265},
#    {'language': '..Mandarin',
#     'speakers': 1000,
#     'speak_english_less_than_very_well': 330},
#    {'language': '..Formosan',
#     'speakers': 250,
#     'speak_english_less_than_very_well': 145}]),
#  ('Kern County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 1744,
#     'speak_english_less_than_very_well': 901},
#    {'language': '..Chinese',
#     'speakers': 870,
#     'speak_english_less_than_very_well': 520},
#    {'language': '..Cantonese',
#     'speakers': 460,
#     'speak_english_less_than_very_well': 265},
#    {'language': '..Mandarin',
#     'speakers': 300,
#     'speak_english_less_than_very_well': 70},
#    {'language': '..Formosan',
#     'speakers': 110,
#     'speak_english_less_than_very_well': 50}]),
#  ('Los Angeles County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 349899,
#     'speak_english_less_than_very_well': 209232},
#    {'language': '..Chinese',
#     'speakers': 174385,
#     'speak_english_less_than_very_well': 109640},
#    {'language': '..Hakka',
#     'speakers': 120,
#     'speak_english_less_than_very_well': 50},
#    {'language': '..Cantonese',
#     'speakers': 71100,
#     'speak_english_less_than_very_well': 41515},
#    {'language': '..Mandarin',
#     'speakers': 89990,
#     'speak_english_less_than_very_well': 49120},
#    {'language': '..Fuchow',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Formosan',
#     'speakers': 14035,
#     'speak_english_less_than_very_well': 8755},
#    {'language': '..Wu',
#     'speakers': 265,
#     'speak_english_less_than_very_well': 160}]),
#  ('Monterey County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2116,
#     'speak_english_less_than_very_well': 907},
#    {'language': '..Chinese',
#     'speakers': 1365,
#     'speak_english_less_than_very_well': 580},
#    {'language': '..Cantonese',
#     'speakers': 265,
#     'speak_english_less_than_very_well': 135},
#    {'language': '..Mandarin',
#     'speakers': 425,
#     'speak_english_less_than_very_well': 145},
#    {'language': '..Formosan',
#     'speakers': 60,
#     'speak_english_less_than_very_well': 50}]),
#  ('Orange County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 65820,
#     'speak_english_less_than_very_well': 30344},
#    {'language': '..Chinese',
#     'speakers': 38385,
#     'speak_english_less_than_very_well': 18140},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Cantonese',
#     'speakers': 5580,
#     'speak_english_less_than_very_well': 2205},
#    {'language': '..Mandarin',
#     'speakers': 16185,
#     'speak_english_less_than_very_well': 6885},
#    {'language': '..Formosan',
#     'speakers': 5535,
#     'speak_english_less_than_very_well': 3090},
#    {'language': '..Wu',
#     'speakers': 130,
#     'speak_english_less_than_very_well': 20}]),
#  ('Placer County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2005,
#     'speak_english_less_than_very_well': 917},
#    {'language': '..Chinese',
#     'speakers': 1250,
#     'speak_english_less_than_very_well': 650},
#    {'language': '..Cantonese',
#     'speakers': 400,
#     'speak_english_less_than_very_well': 160},
#    {'language': '..Mandarin',
#     'speakers': 275,
#     'speak_english_less_than_very_well': 75},
#    {'language': '..Formosan',
#     'speakers': 80,
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Riverside County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 14781,
#     'speak_english_less_than_very_well': 8042},
#    {'language': '..Chinese',
#     'speakers': 8945,
#     'speak_english_less_than_very_well': 5080},
#    {'language': '..Cantonese',
#     'speakers': 2325,
#     'speak_english_less_than_very_well': 970},
#    {'language': '..Mandarin',
#     'speakers': 2710,
#     'speak_english_less_than_very_well': 1405},
#    {'language': '..Formosan',
#     'speakers': 780,
#     'speak_english_less_than_very_well': 560},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Sacramento County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 31501,
#     'speak_english_less_than_very_well': 20050},
#    {'language': '..Chinese',
#     'speakers': 19540,
#     'speak_english_less_than_very_well': 13135},
#    {'language': '..Cantonese',
#     'speakers': 9320,
#     'speak_english_less_than_very_well': 5455},
#    {'language': '..Mandarin',
#     'speakers': 2320,
#     'speak_english_less_than_very_well': 1240},
#    {'language': '..Formosan',
#     'speakers': 325,
#     'speak_english_less_than_very_well': 220}]),
#  ('San Bernardino County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 22525,
#     'speak_english_less_than_very_well': 12453},
#    {'language': '..Chinese',
#     'speakers': 11960,
#     'speak_english_less_than_very_well': 6615},
#    {'language': '..Cantonese',
#     'speakers': 1975,
#     'speak_english_less_than_very_well': 1075},
#    {'language': '..Mandarin',
#     'speakers': 7190,
#     'speak_english_less_than_very_well': 3865},
#    {'language': '..Formosan',
#     'speakers': 1400,
#     'speak_english_less_than_very_well': 895}]),
#  ('San Diego County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 41138,
#     'speak_english_less_than_very_well': 20296},
#    {'language': '..Chinese',
#     'speakers': 27495,
#     'speak_english_less_than_very_well': 14050},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Cantonese',
#     'speakers': 4510,
#     'speak_english_less_than_very_well': 1980},
#    {'language': '..Mandarin',
#     'speakers': 7450,
#     'speak_english_less_than_very_well': 3390},
#    {'language': '..Formosan',
#     'speakers': 1650,
#     'speak_english_less_than_very_well': 875},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('San Francisco County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 143872,
#     'speak_english_less_than_very_well': 92565},
#    {'language': '..Chinese',
#     'speakers': 72135,
#     'speak_english_less_than_very_well': 47960},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Cantonese',
#     'speakers': 59515,
#     'speak_english_less_than_very_well': 38820},
#    {'language': '..Mandarin',
#     'speakers': 11240,
#     'speak_english_less_than_very_well': 5240},
#    {'language': '..Formosan',
#     'speakers': 805,
#     'speak_english_less_than_very_well': 395},
#    {'language': '..Wu',
#     'speakers': 160,
#     'speak_english_less_than_very_well': 135}]),
#  ('San Joaquin County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 7188,
#     'speak_english_less_than_very_well': 4668},
#    {'language': '..Chinese',
#     'speakers': 4395,
#     'speak_english_less_than_very_well': 3070},
#    {'language': '..Cantonese',
#     'speakers': 1985,
#     'speak_english_less_than_very_well': 1180},
#    {'language': '..Mandarin',
#     'speakers': 765,
#     'speak_english_less_than_very_well': 420},
#    {'language': '..Formosan',
#     'speakers': 45,
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('San Mateo County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 51809,
#     'speak_english_less_than_very_well': 24951},
#    {'language': '..Chinese',
#     'speakers': 26745,
#     'speak_english_less_than_very_well': 13510},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Cantonese',
#     'speakers': 16040,
#     'speak_english_less_than_very_well': 6930},
#    {'language': '..Mandarin',
#     'speakers': 7720,
#     'speak_english_less_than_very_well': 3720},
#    {'language': '..Formosan',
#     'speakers': 1280,
#     'speak_english_less_than_very_well': 765},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Santa Barbara County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 3804,
#     'speak_english_less_than_very_well': 1580},
#    {'language': '..Chinese',
#     'speakers': 2310,
#     'speak_english_less_than_very_well': 1020},
#    {'language': '..Cantonese',
#     'speakers': 575,
#     'speak_english_less_than_very_well': 120},
#    {'language': '..Mandarin',
#     'speakers': 805,
#     'speak_english_less_than_very_well': 370},
#    {'language': '..Formosan',
#     'speakers': 115,
#     'speak_english_less_than_very_well': 70}]),
#  ('Santa Clara County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 127202,
#     'speak_english_less_than_very_well': 61658},
#    {'language': '..Chinese',
#     'speakers': 72550,
#     'speak_english_less_than_very_well': 35880},
#    {'language': '..Hakka',
#     'speakers': 35,
#     'speak_english_less_than_very_well': 35},
#    {'language': '..Cantonese',
#     'speakers': 15265,
#     'speak_english_less_than_very_well': 7090},
#    {'language': '..Mandarin',
#     'speakers': 35160,
#     'speak_english_less_than_very_well': 16035},
#    {'language': '..Fuchow',
#     'speakers': 90,
#     'speak_english_less_than_very_well': 65},
#    {'language': '..Formosan',
#     'speakers': 4015,
#     'speak_english_less_than_very_well': 2485},
#    {'language': '..Wu',
#     'speakers': 85,
#     'speak_english_less_than_very_well': 65}]),
#  ('Solano County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 3155,
#     'speak_english_less_than_very_well': 1591},
#    {'language': '..Chinese',
#     'speakers': 1825,
#     'speak_english_less_than_very_well': 960},
#    {'language': '..Cantonese',
#     'speakers': 740,
#     'speak_english_less_than_very_well': 345},
#    {'language': '..Mandarin',
#     'speakers': 525,
#     'speak_english_less_than_very_well': 240},
#    {'language': '..Formosan',
#     'speakers': 60,
#     'speak_english_less_than_very_well': 45}]),
#  ('Sonoma County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2537,
#     'speak_english_less_than_very_well': 1290},
#    {'language': '..Chinese',
#     'speakers': 1365,
#     'speak_english_less_than_very_well': 670},
#    {'language': '..Cantonese',
#     'speakers': 530,
#     'speak_english_less_than_very_well': 325},
#    {'language': '..Mandarin',
#     'speakers': 465,
#     'speak_english_less_than_very_well': 180},
#    {'language': '..Formosan',
#     'speakers': 175,
#     'speak_english_less_than_very_well': 115}]),
#  ('Stanislaus County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2394,
#     'speak_english_less_than_very_well': 1304},
#    {'language': '..Chinese',
#     'speakers': 1260,
#     'speak_english_less_than_very_well': 720},
#    {'language': '..Cantonese',
#     'speakers': 565,
#     'speak_english_less_than_very_well': 375},
#    {'language': '..Mandarin',
#     'speakers': 505,
#     'speak_english_less_than_very_well': 145},
#    {'language': '..Formosan',
#     'speakers': 65,
#     'speak_english_less_than_very_well': 65}]),
#  ('Ventura County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 8010,
#     'speak_english_less_than_very_well': 4025},
#    {'language': '..Chinese',
#     'speakers': 5135,
#     'speak_english_less_than_very_well': 2645},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Cantonese',
#     'speakers': 805,
#     'speak_english_less_than_very_well': 340},
#    {'language': '..Mandarin',
#     'speakers': 1685,
#     'speak_english_less_than_very_well': 805},
#    {'language': '..Formosan',
#     'speakers': 375,
#     'speak_english_less_than_very_well': 230}]),
#  ('Yolo County, CA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 6219,
#     'speak_english_less_than_very_well': 2944},
#    {'language': '..Chinese',
#     'speakers': 3385,
#     'speak_english_less_than_very_well': 1985},
#    {'language': '..Cantonese',
#     'speakers': 1335,
#     'speak_english_less_than_very_well': 345},
#    {'language': '..Mandarin',
#     'speakers': 1380,
#     'speak_english_less_than_very_well': 565},
#    {'language': '..Formosan',
#     'speakers': 120,
#     'speak_english_less_than_very_well': 50}]),
#  ('Arapahoe County, CO',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 3285,
#     'speak_english_less_than_very_well': 1793},
#    {'language': '..Chinese',
#     'speakers': 2440,
#     'speak_english_less_than_very_well': 1450},
#    {'language': '..Cantonese',
#     'speakers': 420,
#     'speak_english_less_than_very_well': 180},
#    {'language': '..Mandarin',
#     'speakers': 280,
#     'speak_english_less_than_very_well': 165},
#    {'language': '..Formosan',
#     'speakers': 145,
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Denver County, CO',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2955,
#     'speak_english_less_than_very_well': 1406},
#    {'language': '..Chinese',
#     'speakers': 2100,
#     'speak_english_less_than_very_well': 1040},
#    {'language': '..Cantonese',
#     'speakers': 255,
#     'speak_english_less_than_very_well': 105},
#    {'language': '..Mandarin',
#     'speakers': 485,
#     'speak_english_less_than_very_well': 185},
#    {'language': '..Formosan',
#     'speakers': 115,
#     'speak_english_less_than_very_well': 75}]),
#  ('El Paso County, CO',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 1816,
#     'speak_english_less_than_very_well': 956},
#    {'language': '..Chinese',
#     'speakers': 1340,
#     'speak_english_less_than_very_well': 750},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Cantonese',
#     'speakers': 220,
#     'speak_english_less_than_very_well': 70},
#    {'language': '..Mandarin',
#     'speakers': 185,
#     'speak_english_less_than_very_well': 105},
#    {'language': '..Formosan',
#     'speakers': 60,
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Fairfield County, CT',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 6967,
#     'speak_english_less_than_very_well': 2987},
#    {'language': '..Chinese',
#     'speakers': 5690,
#     'speak_english_less_than_very_well': 2420},
#    {'language': '..Cantonese',
#     'speakers': 465,
#     'speak_english_less_than_very_well': 150},
#    {'language': '..Mandarin',
#     'speakers': 675,
#     'speak_english_less_than_very_well': 345},
#    {'language': '..Fuchow',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Formosan',
#     'speakers': 90,
#     'speak_english_less_than_very_well': 40},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Hartford County, CT',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 5255,
#     'speak_english_less_than_very_well': 2472},
#    {'language': '..Chinese',
#     'speakers': 4285,
#     'speak_english_less_than_very_well': 2095},
#    {'language': '..Cantonese',
#     'speakers': 390,
#     'speak_english_less_than_very_well': 145},
#    {'language': '..Mandarin',
#     'speakers': 490,
#     'speak_english_less_than_very_well': 195},
#    {'language': '..Formosan',
#     'speakers': 95,
#     'speak_english_less_than_very_well': 40}]),
#  ('New Haven County, CT',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 7646,
#     'speak_english_less_than_very_well': 3574},
#    {'language': '..Chinese',
#     'speakers': 5525,
#     'speak_english_less_than_very_well': 2815},
#    {'language': '..Cantonese',
#     'speakers': 670,
#     'speak_english_less_than_very_well': 270},
#    {'language': '..Mandarin',
#     'speakers': 1185,
#     'speak_english_less_than_very_well': 355},
#    {'language': '..Fuchow',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Formosan',
#     'speakers': 215,
#     'speak_english_less_than_very_well': 105},
#    {'language': '..Wu',
#     'speakers': 40,
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('New Castle County, DE',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 5452,
#     'speak_english_less_than_very_well': 2634},
#    {'language': '..Chinese',
#     'speakers': 4535,
#     'speak_english_less_than_very_well': 2205},
#    {'language': '..Cantonese',
#     'speakers': 235,
#     'speak_english_less_than_very_well': 80},
#    {'language': '..Mandarin',
#     'speakers': 490,
#     'speak_english_less_than_very_well': 285},
#    {'language': '..Formosan',
#     'speakers': 190,
#     'speak_english_less_than_very_well': 70},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('District of Columbia, DC',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 4306,
#     'speak_english_less_than_very_well': 1644},
#    {'language': '..Chinese',
#     'speakers': 2665,
#     'speak_english_less_than_very_well': 1065},
#    {'language': '..Cantonese',
#     'speakers': 555,
#     'speak_english_less_than_very_well': 250},
#    {'language': '..Mandarin',
#     'speakers': 1030,
#     'speak_english_less_than_very_well': 310},
#    {'language': '..Formosan',
#     'speakers': 55,
#     'speak_english_less_than_very_well': 20}]),
#  ('Broward County, FL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 8159,
#     'speak_english_less_than_very_well': 4506},
#    {'language': '..Chinese',
#     'speakers': 5885,
#     'speak_english_less_than_very_well': 3385},
#    {'language': '..Cantonese',
#     'speakers': 1390,
#     'speak_english_less_than_very_well': 705},
#    {'language': '..Mandarin',
#     'speakers': 795,
#     'speak_english_less_than_very_well': 375},
#    {'language': '..Formosan',
#     'speakers': 90,
#     'speak_english_less_than_very_well': 45}]),
#  ('Collier County, FL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 746,
#     'speak_english_less_than_very_well': 445},
#    {'language': '..Chinese',
#     'speakers': 635,
#     'speak_english_less_than_very_well': 410},
#    {'language': '..Cantonese',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Mandarin',
#     'speakers': 55,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Formosan',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Duval County, FL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2533,
#     'speak_english_less_than_very_well': 1207},
#    {'language': '..Chinese',
#     'speakers': 1760,
#     'speak_english_less_than_very_well': 930},
#    {'language': '..Cantonese',
#     'speakers': 65,
#     'speak_english_less_than_very_well': 40},
#    {'language': '..Mandarin',
#     'speakers': 695,
#     'speak_english_less_than_very_well': 230},
#    {'language': '..Formosan',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Hillsborough County, FL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 4473,
#     'speak_english_less_than_very_well': 1864},
#    {'language': '..Chinese',
#     'speakers': 3160,
#     'speak_english_less_than_very_well': 1270},
#    {'language': '..Cantonese',
#     'speakers': 290,
#     'speak_english_less_than_very_well': 190},
#    {'language': '..Mandarin',
#     'speakers': 890,
#     'speak_english_less_than_very_well': 350},
#    {'language': '..Formosan',
#     'speakers': 135,
#     'speak_english_less_than_very_well': 55}]),
#  ('Lee County, FL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 936,
#     'speak_english_less_than_very_well': 426},
#    {'language': '..Chinese',
#     'speakers': 725,
#     'speak_english_less_than_very_well': 330},
#    {'language': '..Cantonese',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Mandarin',
#     'speakers': 190,
#     'speak_english_less_than_very_well': 95},
#    {'language': '..Formosan',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Miami-Dade County, FL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 8878,
#     'speak_english_less_than_very_well': 4776},
#    {'language': '..Chinese',
#     'speakers': 6125,
#     'speak_english_less_than_very_well': 3270},
#    {'language': '..Cantonese',
#     'speakers': 1240,
#     'speak_english_less_than_very_well': 840},
#    {'language': '..Mandarin',
#     'speakers': 1405,
#     'speak_english_less_than_very_well': 605},
#    {'language': '..Formosan',
#     'speakers': 105,
#     'speak_english_less_than_very_well': 55}]),
#  ('Orange County, FL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 6526,
#     'speak_english_less_than_very_well': 3504},
#    {'language': '..Chinese',
#     'speakers': 4720,
#     'speak_english_less_than_very_well': 2595},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Cantonese',
#     'speakers': 865,
#     'speak_english_less_than_very_well': 405},
#    {'language': '..Mandarin',
#     'speakers': 675,
#     'speak_english_less_than_very_well': 295},
#    {'language': '..Formosan',
#     'speakers': 255,
#     'speak_english_less_than_very_well': 210}]),
#  ('Palm Beach County, FL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 5041,
#     'speak_english_less_than_very_well': 2801},
#    {'language': '..Chinese',
#     'speakers': 3605,
#     'speak_english_less_than_very_well': 1985},
#    {'language': '..Cantonese',
#     'speakers': 830,
#     'speak_english_less_than_very_well': 440},
#    {'language': '..Mandarin',
#     'speakers': 535,
#     'speak_english_less_than_very_well': 315},
#    {'language': '..Formosan',
#     'speakers': 70,
#     'speak_english_less_than_very_well': 60}]),
#  ('Pinellas County, FL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2563,
#     'speak_english_less_than_very_well': 1520},
#    {'language': '..Chinese',
#     'speakers': 2045,
#     'speak_english_less_than_very_well': 1410},
#    {'language': '..Cantonese',
#     'speakers': 300,
#     'speak_english_less_than_very_well': 55},
#    {'language': '..Mandarin',
#     'speakers': 185,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Formosan',
#     'speakers': 30,
#     'speak_english_less_than_very_well': 30}]),
#  ('Cobb County, GA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 4610,
#     'speak_english_less_than_very_well': 1728},
#    {'language': '..Chinese',
#     'speakers': 3485,
#     'speak_english_less_than_very_well': 1475},
#    {'language': '..Cantonese',
#     'speakers': 195,
#     'speak_english_less_than_very_well': 35},
#    {'language': '..Mandarin',
#     'speakers': 890,
#     'speak_english_less_than_very_well': 200},
#    {'language': '..Formosan',
#     'speakers': 40,
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('DeKalb County, GA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 6184,
#     'speak_english_less_than_very_well': 3451},
#    {'language': '..Chinese',
#     'speakers': 4335,
#     'speak_english_less_than_very_well': 2740},
#    {'language': '..Kan, Hsiang',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Cantonese',
#     'speakers': 245,
#     'speak_english_less_than_very_well': 120},
#    {'language': '..Mandarin',
#     'speakers': 1370,
#     'speak_english_less_than_very_well': 545},
#    {'language': '..Formosan',
#     'speakers': 195,
#     'speak_english_less_than_very_well': 10}]),
#  ('Fulton County, GA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 9502,
#     'speak_english_less_than_very_well': 4328},
#    {'language': '..Chinese',
#     'speakers': 7190,
#     'speak_english_less_than_very_well': 3405},
#    {'language': '..Cantonese',
#     'speakers': 405,
#     'speak_english_less_than_very_well': 205},
#    {'language': '..Mandarin',
#     'speakers': 1660,
#     'speak_english_less_than_very_well': 655},
#    {'language': '..Formosan',
#     'speakers': 240,
#     'speak_english_less_than_very_well': 65},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Gwinnett County, GA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 10656,
#     'speak_english_less_than_very_well': 6028},
#    {'language': '..Chinese',
#     'speakers': 7040,
#     'speak_english_less_than_very_well': 4240},
#    {'language': '..Cantonese',
#     'speakers': 1225,
#     'speak_english_less_than_very_well': 465},
#    {'language': '..Mandarin',
#     'speakers': 2050,
#     'speak_english_less_than_very_well': 1140},
#    {'language': '..Formosan',
#     'speakers': 340,
#     'speak_english_less_than_very_well': 180}]),
#  ('Hawaii County, HI',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 463,
#     'speak_english_less_than_very_well': 182},
#    {'language': '..Chinese',
#     'speakers': 250,
#     'speak_english_less_than_very_well': 155},
#    {'language': '..Cantonese',
#     'speakers': 70,
#     'speak_english_less_than_very_well': 25},
#    {'language': '..Mandarin',
#     'speakers': 140,
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Honolulu County, HI',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 29933,
#     'speak_english_less_than_very_well': 19142},
#    {'language': '..Chinese',
#     'speakers': 16790,
#     'speak_english_less_than_very_well': 10160},
#    {'language': '..Cantonese',
#     'speakers': 7805,
#     'speak_english_less_than_very_well': 5350},
#    {'language': '..Mandarin',
#     'speakers': 4700,
#     'speak_english_less_than_very_well': 3150},
#    {'language': '..Fuchow',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Formosan',
#     'speakers': 620,
#     'speak_english_less_than_very_well': 480},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Maui County, HI',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 827,
#     'speak_english_less_than_very_well': 448},
#    {'language': '..Chinese',
#     'speakers': 210,
#     'speak_english_less_than_very_well': 85},
#    {'language': '..Cantonese',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Mandarin',
#     'speakers': 605,
#     'speak_english_less_than_very_well': 360}]),
#  ('Cook County, IL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 57563,
#     'speak_english_less_than_very_well': 31858},
#    {'language': '..Chinese',
#     'speakers': 39185,
#     'speak_english_less_than_very_well': 22490},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Cantonese',
#     'speakers': 11355,
#     'speak_english_less_than_very_well': 6605},
#    {'language': '..Mandarin',
#     'speakers': 5970,
#     'speak_english_less_than_very_well': 2235},
#    {'language': '..Fuchow',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Formosan',
#     'speakers': 1010,
#     'speak_english_less_than_very_well': 500}]),
#  ('DuPage County, IL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 12119,
#     'speak_english_less_than_very_well': 5672},
#    {'language': '..Chinese',
#     'speakers': 8225,
#     'speak_english_less_than_very_well': 4030},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Cantonese',
#     'speakers': 740,
#     'speak_english_less_than_very_well': 255},
#    {'language': '..Mandarin',
#     'speakers': 2495,
#     'speak_english_less_than_very_well': 1115},
#    {'language': '..Formosan',
#     'speakers': 650,
#     'speak_english_less_than_very_well': 275}]),
#  ('Kane County, IL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 1449,
#     'speak_english_less_than_very_well': 595},
#    {'language': '..Chinese',
#     'speakers': 1115,
#     'speak_english_less_than_very_well': 475},
#    {'language': '..Cantonese',
#     'speakers': 200,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Mandarin',
#     'speakers': 80,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Formosan',
#     'speakers': 55,
#     'speak_english_less_than_very_well': 55}]),
#  ('Lake County, IL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 6723,
#     'speak_english_less_than_very_well': 2524},
#    {'language': '..Chinese',
#     'speakers': 5210,
#     'speak_english_less_than_very_well': 1920},
#    {'language': '..Cantonese',
#     'speakers': 510,
#     'speak_english_less_than_very_well': 255},
#    {'language': '..Mandarin',
#     'speakers': 765,
#     'speak_english_less_than_very_well': 215},
#    {'language': '..Formosan',
#     'speakers': 240,
#     'speak_english_less_than_very_well': 130}]),
#  ('Will County, IL',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 3607,
#     'speak_english_less_than_very_well': 1899},
#    {'language': '..Chinese',
#     'speakers': 2635,
#     'speak_english_less_than_very_well': 1485},
#    {'language': '..Cantonese',
#     'speakers': 315,
#     'speak_english_less_than_very_well': 180},
#    {'language': '..Mandarin',
#     'speakers': 575,
#     'speak_english_less_than_very_well': 185},
#    {'language': '..Formosan',
#     'speakers': 85,
#     'speak_english_less_than_very_well': 55}]),
#  ('Marion County, IN',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 3743,
#     'speak_english_less_than_very_well': 2754},
#    {'language': '..Chinese',
#     'speakers': 3110,
#     'speak_english_less_than_very_well': 2430},
#    {'language': '..Cantonese',
#     'speakers': 125,
#     'speak_english_less_than_very_well': 30},
#    {'language': '..Mandarin',
#     'speakers': 440,
#     'speak_english_less_than_very_well': 245},
#    {'language': '..Fuchow',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Formosan',
#     'speakers': 60,
#     'speak_english_less_than_very_well': 45}]),
#  ('Polk County, IA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 1802,
#     'speak_english_less_than_very_well': 779},
#    {'language': '..Chinese',
#     'speakers': 1595,
#     'speak_english_less_than_very_well': 680},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Cantonese',
#     'speakers': 110,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Mandarin',
#     'speakers': 85,
#     'speak_english_less_than_very_well': 75}]),
#  ('Johnson County, KS',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 3683,
#     'speak_english_less_than_very_well': 1490},
#    {'language': '..Chinese',
#     'speakers': 2800,
#     'speak_english_less_than_very_well': 1185},
#    {'language': '..Cantonese',
#     'speakers': 225,
#     'speak_english_less_than_very_well': 100},
#    {'language': '..Mandarin',
#     'speakers': 520,
#     'speak_english_less_than_very_well': 155},
#    {'language': '..Formosan',
#     'speakers': 135,
#     'speak_english_less_than_very_well': 55}]),
#  ('Jefferson County, KY',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 1879,
#     'speak_english_less_than_very_well': 923},
#    {'language': '..Chinese',
#     'speakers': 1715,
#     'speak_english_less_than_very_well': 860},
#    {'language': '..Cantonese',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Mandarin',
#     'speakers': 105,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Formosan',
#     'speakers': 40,
#     'speak_english_less_than_very_well': 40}]),
#  ('Jefferson Parish, LA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 1937,
#     'speak_english_less_than_very_well': 1015},
#    {'language': '..Chinese',
#     'speakers': 1720,
#     'speak_english_less_than_very_well': 925},
#    {'language': '..Cantonese',
#     'speakers': 40,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Mandarin',
#     'speakers': 60,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Formosan',
#     'speakers': 115,
#     'speak_english_less_than_very_well': 60}]),
#  ('Anne Arundel County, MD',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 1980,
#     'speak_english_less_than_very_well': 685},
#    {'language': '..Chinese',
#     'speakers': 1440,
#     'speak_english_less_than_very_well': 515},
#    {'language': '..Cantonese',
#     'speakers': 205,
#     'speak_english_less_than_very_well': 120},
#    {'language': '..Mandarin',
#     'speakers': 235,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Formosan',
#     'speakers': 80,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Baltimore County, MD',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 5368,
#     'speak_english_less_than_very_well': 3022},
#    {'language': '..Chinese',
#     'speakers': 4205,
#     'speak_english_less_than_very_well': 2350},
#    {'language': '..Cantonese',
#     'speakers': 270,
#     'speak_english_less_than_very_well': 155},
#    {'language': '..Mandarin',
#     'speakers': 680,
#     'speak_english_less_than_very_well': 360},
#    {'language': '..Formosan',
#     'speakers': 205,
#     'speak_english_less_than_very_well': 155},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Howard County, MD',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 7185,
#     'speak_english_less_than_very_well': 2978},
#    {'language': '..Chinese',
#     'speakers': 5775,
#     'speak_english_less_than_very_well': 2565},
#    {'language': '..Cantonese',
#     'speakers': 595,
#     'speak_english_less_than_very_well': 185},
#    {'language': '..Mandarin',
#     'speakers': 655,
#     'speak_english_less_than_very_well': 150},
#    {'language': '..Formosan',
#     'speakers': 160,
#     'speak_english_less_than_very_well': 80}]),
#  ('Montgomery County, MD',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 34986,
#     'speak_english_less_than_very_well': 15946},
#    {'language': '..Chinese',
#     'speakers': 26460,
#     'speak_english_less_than_very_well': 12350},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Cantonese',
#     'speakers': 1790,
#     'speak_english_less_than_very_well': 930},
#    {'language': '..Mandarin',
#     'speakers': 5405,
#     'speak_english_less_than_very_well': 2035},
#    {'language': '..Formosan',
#     'speakers': 1295,
#     'speak_english_less_than_very_well': 625},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Prince George s County, MD',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 5175,
#     'speak_english_less_than_very_well': 2661},
#    {'language': '..Chinese',
#     'speakers': 3830,
#     'speak_english_less_than_very_well': 2065},
#    {'language': '..Cantonese',
#     'speakers': 505,
#     'speak_english_less_than_very_well': 225},
#    {'language': '..Mandarin',
#     'speakers': 770,
#     'speak_english_less_than_very_well': 355},
#    {'language': '..Formosan',
#     'speakers': 75,
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Baltimore city, MD',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2858,
#     'speak_english_less_than_very_well': 1265},
#    {'language': '..Chinese',
#     'speakers': 1910,
#     'speak_english_less_than_very_well': 1015},
#    {'language': '..Cantonese',
#     'speakers': 170,
#     'speak_english_less_than_very_well': 50},
#    {'language': '..Mandarin',
#     'speakers': 640,
#     'speak_english_less_than_very_well': 165},
#    {'language': '..Formosan',
#     'speakers': 130,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Bristol County, MA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 1876,
#     'speak_english_less_than_very_well': 892},
#    {'language': '..Chinese',
#     'speakers': 1170,
#     'speak_english_less_than_very_well': 675},
#    {'language': '..Cantonese',
#     'speakers': 155,
#     'speak_english_less_than_very_well': 80},
#    {'language': '..Mandarin',
#     'speakers': 550,
#     'speak_english_less_than_very_well': 135}]),
#  ('Essex County, MA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 4527,
#     'speak_english_less_than_very_well': 2085},
#    {'language': '..Chinese',
#     'speakers': 3320,
#     'speak_english_less_than_very_well': 1590},
#    {'language': '..Cantonese',
#     'speakers': 605,
#     'speak_english_less_than_very_well': 370},
#    {'language': '..Mandarin',
#     'speakers': 545,
#     'speak_english_less_than_very_well': 115},
#    {'language': '..Fuchow',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Formosan',
#     'speakers': 50,
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Hampden County, MA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 1407,
#     'speak_english_less_than_very_well': 785},
#    {'language': '..Chinese',
#     'speakers': 1125,
#     'speak_english_less_than_very_well': 705},
#    {'language': '..Cantonese',
#     'speakers': 185,
#     'speak_english_less_than_very_well': 50},
#    {'language': '..Mandarin',
#     'speakers': 90,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Formosan',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Middlesex County, MA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 41269,
#     'speak_english_less_than_very_well': 19706},
#    {'language': '..Chinese',
#     'speakers': 27100,
#     'speak_english_less_than_very_well': 13000},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Cantonese',
#     'speakers': 6065,
#     'speak_english_less_than_very_well': 3200},
#    {'language': '..Mandarin',
#     'speakers': 7060,
#     'speak_english_less_than_very_well': 3060},
#    {'language': '..Fuchow',
#     'speakers': 45,
#     'speak_english_less_than_very_well': 45},
#    {'language': '..Formosan',
#     'speakers': 990,
#     'speak_english_less_than_very_well': 400}]),
#  ('Norfolk County, MA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 25718,
#     'speak_english_less_than_very_well': 14481},
#    {'language': '..Chinese',
#     'speakers': 16000,
#     'speak_english_less_than_very_well': 8795},
#    {'language': '..Cantonese',
#     'speakers': 6095,
#     'speak_english_less_than_very_well': 3845},
#    {'language': '..Mandarin',
#     'speakers': 3035,
#     'speak_english_less_than_very_well': 1500},
#    {'language': '..Fuchow',
#     'speakers': 165,
#     'speak_english_less_than_very_well': 165},
#    {'language': '..Formosan',
#     'speakers': 400,
#     'speak_english_less_than_very_well': 170},
#    {'language': '..Wu',
#     'speakers': 20,
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Plymouth County, MA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 1197,
#     'speak_english_less_than_very_well': 496},
#    {'language': '..Chinese',
#     'speakers': 790,
#     'speak_english_less_than_very_well': 330},
#    {'language': '..Cantonese',
#     'speakers': 215,
#     'speak_english_less_than_very_well': 105},
#    {'language': '..Mandarin',
#     'speakers': 190,
#     'speak_english_less_than_very_well': 60}]),
#  ('Suffolk County, MA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 22345,
#     'speak_english_less_than_very_well': 13817},
#    {'language': '..Chinese',
#     'speakers': 14645,
#     'speak_english_less_than_very_well': 9500},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Cantonese',
#     'speakers': 4720,
#     'speak_english_less_than_very_well': 3005},
#    {'language': '..Mandarin',
#     'speakers': 2715,
#     'speak_english_less_than_very_well': 1270},
#    {'language': '..Formosan',
#     'speakers': 205,
#     'speak_english_less_than_very_well': 45},
#    {'language': '..Wu',
#     'speakers': 40,
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Worcester County, MA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 5571,
#     'speak_english_less_than_very_well': 2756},
#    {'language': '..Chinese',
#     'speakers': 4165,
#     'speak_english_less_than_very_well': 2150},
#    {'language': '..Cantonese',
#     'speakers': 445,
#     'speak_english_less_than_very_well': 210},
#    {'language': '..Mandarin',
#     'speakers': 880,
#     'speak_english_less_than_very_well': 375},
#    {'language': '..Formosan',
#     'speakers': 80,
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Macomb County, MI',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2556,
#     'speak_english_less_than_very_well': 1523},
#    {'language': '..Chinese',
#     'speakers': 1950,
#     'speak_english_less_than_very_well': 1140},
#    {'language': '..Cantonese',
#     'speakers': 300,
#     'speak_english_less_than_very_well': 170},
#    {'language': '..Mandarin',
#     'speakers': 300,
#     'speak_english_less_than_very_well': 215},
#    {'language': '..Formosan',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Oakland County, MI',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 10363,
#     'speak_english_less_than_very_well': 4327},
#    {'language': '..Chinese',
#     'speakers': 8200,
#     'speak_english_less_than_very_well': 3310},
#    {'language': '..Cantonese',
#     'speakers': 635,
#     'speak_english_less_than_very_well': 290},
#    {'language': '..Mandarin',
#     'speakers': 1240,
#     'speak_english_less_than_very_well': 515},
#    {'language': '..Formosan',
#     'speakers': 265,
#     'speak_english_less_than_very_well': 205},
#    {'language': '..Wu',
#     'speakers': 25,
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Washtenaw County, MI',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 8632,
# ...
#    {'language': '..Formosan',
#     'speakers': 170,
#     'speak_english_less_than_very_well': 125}]),
#  ('Philadelphia County, PA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 26342,
#     'speak_english_less_than_very_well': 17851},
#    {'language': '..Chinese',
#     'speakers': 18725,
#     'speak_english_less_than_very_well': 12695},
#    {'language': '..Cantonese',
#     'speakers': 4005,
#     'speak_english_less_than_very_well': 2740},
#    {'language': '..Mandarin',
#     'speakers': 3215,
#     'speak_english_less_than_very_well': 2165},
#    {'language': '..Fuchow',
#     'speakers': 125,
#     'speak_english_less_than_very_well': 125},
#    {'language': '..Formosan',
#     'speakers': 280,
#     'speak_english_less_than_very_well': 125}]),
#  ('Providence County, RI',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 4358,
#     'speak_english_less_than_very_well': 2404},
#    {'language': '..Chinese',
#     'speakers': 3115,
#     'speak_english_less_than_very_well': 1935},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Cantonese',
#     'speakers': 425,
#     'speak_english_less_than_very_well': 185},
#    {'language': '..Mandarin',
#     'speakers': 635,
#     'speak_english_less_than_very_well': 165},
#    {'language': '..Formosan',
#     'speakers': 160,
#     'speak_english_less_than_very_well': 110}]),
#  ('Davidson County, TN',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2467,
#     'speak_english_less_than_very_well': 1166},
#    {'language': '..Chinese',
#     'speakers': 1990,
#     'speak_english_less_than_very_well': 985},
#    {'language': '..Cantonese',
#     'speakers': 135,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Mandarin',
#     'speakers': 270,
#     'speak_english_less_than_very_well': 130},
#    {'language': '..Formosan',
#     'speakers': 60,
#     'speak_english_less_than_very_well': 40},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Shelby County, TN',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 3330,
#     'speak_english_less_than_very_well': 1476},
#    {'language': '..Chinese',
#     'speakers': 2555,
#     'speak_english_less_than_very_well': 1075},
#    {'language': '..Cantonese',
#     'speakers': 165,
#     'speak_english_less_than_very_well': 80},
#    {'language': '..Mandarin',
#     'speakers': 560,
#     'speak_english_less_than_very_well': 305},
#    {'language': '..Formosan',
#     'speakers': 50,
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Bexar County, TX',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 4350,
#     'speak_english_less_than_very_well': 2152},
#    {'language': '..Chinese',
#     'speakers': 3260,
#     'speak_english_less_than_very_well': 1810},
#    {'language': '..Cantonese',
#     'speakers': 335,
#     'speak_english_less_than_very_well': 105},
#    {'language': '..Mandarin',
#     'speakers': 655,
#     'speak_english_less_than_very_well': 235},
#    {'language': '..Formosan',
#     'speakers': 100,
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Collin County, TX',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 19026,
#     'speak_english_less_than_very_well': 8751},
#    {'language': '..Chinese',
#     'speakers': 13930,
#     'speak_english_less_than_very_well': 6495},
#    {'language': '..Hakka',
#     'speakers': 45,
#     'speak_english_less_than_very_well': 45},
#    {'language': '..Cantonese',
#     'speakers': 920,
#     'speak_english_less_than_very_well': 485},
#    {'language': '..Mandarin',
#     'speakers': 3400,
#     'speak_english_less_than_very_well': 1295},
#    {'language': '..Formosan',
#     'speakers': 725,
#     'speak_english_less_than_very_well': 430},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Dallas County, TX',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 11694,
#     'speak_english_less_than_very_well': 6046},
#    {'language': '..Chinese',
#     'speakers': 8965,
#     'speak_english_less_than_very_well': 4815},
#    {'language': '..Hakka',
#     'speakers': 50,
#     'speak_english_less_than_very_well': 50},
#    {'language': '..Cantonese',
#     'speakers': 590,
#     'speak_english_less_than_very_well': 215},
#    {'language': '..Mandarin',
#     'speakers': 1660,
#     'speak_english_less_than_very_well': 730},
#    {'language': '..Formosan',
#     'speakers': 410,
#     'speak_english_less_than_very_well': 235},
#    {'language': '..Wu',
#     'speakers': 20,
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Denton County, TX',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 6147,
#     'speak_english_less_than_very_well': 3122},
#    {'language': '..Chinese',
#     'speakers': 4715,
#     'speak_english_less_than_very_well': 2545},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Cantonese',
#     'speakers': 170,
#     'speak_english_less_than_very_well': 40},
#    {'language': '..Mandarin',
#     'speakers': 1105,
#     'speak_english_less_than_very_well': 495},
#    {'language': '..Formosan',
#     'speakers': 155,
#     'speak_english_less_than_very_well': 40}]),
#  ('Fort Bend County, TX',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 19433,
#     'speak_english_less_than_very_well': 8614},
#    {'language': '..Chinese',
#     'speakers': 14190,
#     'speak_english_less_than_very_well': 6350},
#    {'language': '..Cantonese',
#     'speakers': 1720,
#     'speak_english_less_than_very_well': 705},
#    {'language': '..Mandarin',
#     'speakers': 2565,
#     'speak_english_less_than_very_well': 930},
#    {'language': '..Formosan',
#     'speakers': 960,
#     'speak_english_less_than_very_well': 630}]),
#  ('Harris County, TX',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 39921,
#     'speak_english_less_than_very_well': 21365},
#    {'language': '..Chinese',
#     'speakers': 28485,
#     'speak_english_less_than_very_well': 16015},
#    {'language': '..Cantonese',
#     'speakers': 4010,
#     'speak_english_less_than_very_well': 2330},
#    {'language': '..Mandarin',
#     'speakers': 6055,
#     'speak_english_less_than_very_well': 2250},
#    {'language': '..Formosan',
#     'speakers': 1360,
#     'speak_english_less_than_very_well': 755},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Tarrant County, TX',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 6809,
#     'speak_english_less_than_very_well': 2769},
#    {'language': '..Chinese',
#     'speakers': 4440,
#     'speak_english_less_than_very_well': 2145},
#    {'language': '..Cantonese',
#     'speakers': 570,
#     'speak_english_less_than_very_well': 200},
#    {'language': '..Mandarin',
#     'speakers': 1360,
#     'speak_english_less_than_very_well': 345},
#    {'language': '..Formosan',
#     'speakers': 440,
#     'speak_english_less_than_very_well': 80}]),
#  ('Travis County, TX',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 10469,
#     'speak_english_less_than_very_well': 3940},
#    {'language': '..Chinese',
#     'speakers': 6985,
#     'speak_english_less_than_very_well': 2985},
#    {'language': '..Cantonese',
#     'speakers': 725,
#     'speak_english_less_than_very_well': 245},
#    {'language': '..Mandarin',
#     'speakers': 2490,
#     'speak_english_less_than_very_well': 615},
#    {'language': '..Formosan',
#     'speakers': 270,
#     'speak_english_less_than_very_well': 95}]),
#  ('Salt Lake County, UT',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 6594,
#     'speak_english_less_than_very_well': 3416},
#    {'language': '..Chinese',
#     'speakers': 4555,
#     'speak_english_less_than_very_well': 2545},
#    {'language': '..Hakka',
#     'speakers': 55,
#     'speak_english_less_than_very_well': 45},
#    {'language': '..Cantonese',
#     'speakers': 795,
#     'speak_english_less_than_very_well': 370},
#    {'language': '..Mandarin',
#     'speakers': 935,
#     'speak_english_less_than_very_well': 285},
#    {'language': '..Formosan',
#     'speakers': 225,
#     'speak_english_less_than_very_well': 145},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Arlington County, VA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2704,
#     'speak_english_less_than_very_well': 994},
#    {'language': '..Chinese',
#     'speakers': 1725,
#     'speak_english_less_than_very_well': 635},
#    {'language': '..Cantonese',
#     'speakers': 405,
#     'speak_english_less_than_very_well': 70},
#    {'language': '..Mandarin',
#     'speakers': 520,
#     'speak_english_less_than_very_well': 275},
#    {'language': '..Formosan',
#     'speakers': 55,
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Fairfax County, VA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 23022,
#     'speak_english_less_than_very_well': 10361},
#    {'language': '..Chinese',
#     'speakers': 16565,
#     'speak_english_less_than_very_well': 7315},
#    {'language': '..Cantonese',
#     'speakers': 1850,
#     'speak_english_less_than_very_well': 805},
#    {'language': '..Mandarin',
#     'speakers': 3740,
#     'speak_english_less_than_very_well': 1775},
#    {'language': '..Fuchow',
#     'speakers': 65,
#     'speak_english_less_than_very_well': 65},
#    {'language': '..Formosan',
#     'speakers': 790,
#     'speak_english_less_than_very_well': 400},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Henrico County, VA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2431,
#     'speak_english_less_than_very_well': 1131},
#    {'language': '..Chinese',
#     'speakers': 2085,
#     'speak_english_less_than_very_well': 960},
#    {'language': '..Cantonese',
#     'speakers': 200,
#     'speak_english_less_than_very_well': 140},
#    {'language': '..Mandarin',
#     'speakers': 130,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Formosan',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Loudoun County, VA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 3674,
#     'speak_english_less_than_very_well': 1558},
#    {'language': '..Chinese',
#     'speakers': 2850,
#     'speak_english_less_than_very_well': 1220},
#    {'language': '..Cantonese',
#     'speakers': 485,
#     'speak_english_less_than_very_well': 235},
#    {'language': '..Mandarin',
#     'speakers': 285,
#     'speak_english_less_than_very_well': 65},
#    {'language': '..Formosan',
#     'speakers': 55,
#     'speak_english_less_than_very_well': 40}]),
#  ('Prince William County, VA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 1968,
#     'speak_english_less_than_very_well': 776},
#    {'language': '..Chinese',
#     'speakers': 1560,
#     'speak_english_less_than_very_well': 660},
#    {'language': '..Cantonese',
#     'speakers': 145,
#     'speak_english_less_than_very_well': '(B)'},
#    {'language': '..Mandarin',
#     'speakers': 155,
#     'speak_english_less_than_very_well': 70},
#    {'language': '..Formosan',
#     'speakers': 110,
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Virginia Beach city, VA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 1943,
#     'speak_english_less_than_very_well': 1013},
#    {'language': '..Chinese',
#     'speakers': 1265,
#     'speak_english_less_than_very_well': 640},
#    {'language': '..Cantonese',
#     'speakers': 125,
#     'speak_english_less_than_very_well': 90},
#    {'language': '..Mandarin',
#     'speakers': 485,
#     'speak_english_less_than_very_well': 260},
#    {'language': '..Formosan',
#     'speakers': 45,
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'}]),
#  ('Clark County, WA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2651,
#     'speak_english_less_than_very_well': 1413},
#    {'language': '..Chinese',
#     'speakers': 1915,
#     'speak_english_less_than_very_well': 1100},
#    {'language': '..Cantonese',
#     'speakers': 115,
#     'speak_english_less_than_very_well': 40},
#    {'language': '..Mandarin',
#     'speakers': 375,
#     'speak_english_less_than_very_well': 115},
#    {'language': '..Formosan',
#     'speakers': 250,
#     'speak_english_less_than_very_well': 160}]),
#  ('King County, WA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 60327,
#     'speak_english_less_than_very_well': 30740},
#    {'language': '..Chinese',
#     'speakers': 38030,
#     'speak_english_less_than_very_well': 20025},
#    {'language': '..Hakka',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(D)'},
#    {'language': '..Cantonese',
#     'speakers': 9845,
#     'speak_english_less_than_very_well': 5215},
#    {'language': '..Mandarin',
#     'speakers': 10505,
#     'speak_english_less_than_very_well': 4485},
#    {'language': '..Formosan',
#     'speakers': 1910,
#     'speak_english_less_than_very_well': 1005},
#    {'language': '..Wu',
#     'speakers': '(D)',
#     'speak_english_less_than_very_well': '(B)'}]),
#  ('Pierce County, WA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2341,
#     'speak_english_less_than_very_well': 1086},
#    {'language': '..Chinese',
#     'speakers': 1665,
#     'speak_english_less_than_very_well': 785},
#    {'language': '..Cantonese',
#     'speakers': 410,
#     'speak_english_less_than_very_well': 200},
#    {'language': '..Mandarin',
#     'speakers': 215,
#     'speak_english_less_than_very_well': 80},
#    {'language': '..Formosan',
#     'speakers': 50,
#     'speak_english_less_than_very_well': 20}]),
#  ('Snohomish County, WA',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 8279,
#     'speak_english_less_than_very_well': 4573},
#    {'language': '..Chinese',
#     'speakers': 5065,
#     'speak_english_less_than_very_well': 2705},
#    {'language': '..Cantonese',
#     'speakers': 1615,
#     'speak_english_less_than_very_well': 1015},
#    {'language': '..Mandarin',
#     'speakers': 1470,
#     'speak_english_less_than_very_well': 790},
#    {'language': '..Formosan',
#     'speakers': 130,
#     'speak_english_less_than_very_well': 65}]),
#  ('Dane County, WI',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 5417,
#     'speak_english_less_than_very_well': 2728},
#    {'language': '..Chinese',
#     'speakers': 4430,
#     'speak_english_less_than_very_well': 2225},
#    {'language': '..Cantonese',
#     'speakers': 215,
#     'speak_english_less_than_very_well': 125},
#    {'language': '..Mandarin',
#     'speakers': 675,
#     'speak_english_less_than_very_well': 320},
#    {'language': '..Formosan',
#     'speakers': 95,
#     'speak_english_less_than_very_well': 55}]),
#  ('Milwaukee County, WI',
#   [{'language': '.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#     'speakers': 2974,
#     'speak_english_less_than_very_well': 1761},
#    {'language': '..Chinese',
#     'speakers': 2360,
#     'speak_english_less_than_very_well': 1475},
#    {'language': '..Cantonese',
#     'speakers': 170,
#     'speak_english_less_than_very_well': 60},
#    {'language': '..Mandarin',
#     'speakers': 415,
#     'speak_english_less_than_very_well': 205},
#    {'language': '..Formosan',
#     'speakers': 35,
#     'speak_english_less_than_very_well': '(D)'}])]

# %%
# Get all dialects in census data
dialects = set()
for county, languages in language_by_county: 
    for language in languages: 
        dialects.add(language["language"])
        
dialects = sorted(list(dialects), reverse = True)
dialects
# Out:
# ['.Chinese (incl. Cantonese, Mandarin, other Chinese languages4)',
#  '..Wu',
#  '..Mandarin',
#  '..Kan, Hsiang',
#  '..Hakka',
#  '..Fuchow',
#  '..Formosan',
#  '..Chinese',
#  '..Cantonese']

# %%
# Let's create a dataframe with the data now 
rows = []

for county, languages in language_by_county: 
    row = {"County": county}
    
    for language in languages: 
        row[language["language"]] = language["speakers"] if language["speakers"] != "(D)" else None

    rows.append(row)
    
language_df = pd.DataFrame(rows, columns = ["County"] + dialects)

# %%
language_df.head()
# Out:
#                        County  \
# 0  Anchorage Municipality, AK
# 1         Maricopa County, AZ
# 2           Navajo County, AZ
# 3             Pima County, AZ
# 4          Alameda County, CA
#
#    .Chinese (incl. Cantonese, Mandarin, other Chinese languages4)   ..Wu  \
# 0                                                882                 NaN
# 1                                              20337                 NaN
# 2                                                 35                 NaN
# 3                                               6334                 NaN
# 4                                             119759               135.0
#
#    ..Mandarin  ..Kan, Hsiang  ..Hakka  ..Fuchow  ..Formosan  ..Chinese  \
# 0        95.0            NaN      NaN       NaN         NaN      740.0
# 1      3890.0            NaN      NaN       NaN       450.0    13750.0
# 2         NaN            NaN      NaN       NaN         NaN        NaN
# 3       955.0            NaN      NaN       NaN       125.0     4625.0
# 4     17450.0            NaN     45.0       NaN      1915.0    69165.0
#
#    ..Cantonese
# 0         40.0
# 1       2235.0
# 2          NaN
# 3        630.0
# 4      31050.0

# %%
# Let's make these columns more readable 
language_df.columns = [d.replace(".", "") for d in language_df.columns]
language_df.rename(columns={'Chinese (incl Cantonese, Mandarin, other Chinese languages4)':'Chinese (Total)'}, inplace=True)
language_df.head()
# Out:
#                        County  Chinese (Total)     Wu  Mandarin  Kan, Hsiang  \
# 0  Anchorage Municipality, AK              882    NaN      95.0          NaN
# 1         Maricopa County, AZ            20337    NaN    3890.0          NaN
# 2           Navajo County, AZ               35    NaN       NaN          NaN
# 3             Pima County, AZ             6334    NaN     955.0          NaN
# 4          Alameda County, CA           119759  135.0   17450.0          NaN
#
#    Hakka  Fuchow  Formosan  Chinese  Cantonese
# 0    NaN     NaN       NaN    740.0       40.0
# 1    NaN     NaN     450.0  13750.0     2235.0
# 2    NaN     NaN       NaN      NaN        NaN
# 3    NaN     NaN     125.0   4625.0      630.0
# 4   45.0     NaN    1915.0  69165.0    31050.0

# %%
# Save the data 
language_df.to_csv("languages.csv")
